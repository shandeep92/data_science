# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Recommender Systems
#
# _Authors: Riley Dallas (AUS)_
#
# ---

# %%
import pandas as pd
from scipy import sparse
from sklearn.metrics.pairwise import pairwise_distances

# %% [markdown]
# ## Load `movies.csv` and `ratings.csv`
# ---
#
# We'll be using the [MovieLens](https://grouplens.org/datasets/movielens/) dataset for building our recommendation engine. There are two CSVs (`movies.csv` and `ratings.csv`) that we'll eventually inner join.

# %%
movies = pd.read_csv('./ml-latest-small/movies.csv')
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings = pd.read_csv('./ml-latest-small/ratings.csv')
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %% [markdown]
# ## Drop unnecessary columns
# ---
#
# We won't need the `timestamp` column from `ratings`, nor will we need the `genres` column from `movies`. Drop both columns in the cells below.

# %%
ratings.drop('timestamp', axis=1, inplace=True)
movies.drop('genres', axis=1,inplace=True)

# %% [markdown]
# ## Merge `movies` and `ratings`
# ---
#
# Use `pd.merge` to **inner join** `movies` with `ratings` on the `movieId` column.

# %%
df = pd.merge(ratings, movies, on ='movieId')
df.shape
# Out:
# (100836, 4)

# %%
df.head()
# Out:
#    userId  movieId  rating             title
# 0       1        1     4.0  Toy Story (1995)
# 1       5        1     4.0  Toy Story (1995)
# 2       7        1     4.5  Toy Story (1995)
# 3      15        1     2.5  Toy Story (1995)
# 4      17        1     4.5  Toy Story (1995)

# %% [markdown]
# ## Create pivot table
# ---
#
# Because we're creating an item-based collaborative recommender (where item in this case is our movies), we'll set up our pivot table as follows:
# 1. The `title` will be the index
# 2. The `userId` will be the column
# 3. The `rating` will be the value
#
# **If we were building a user-based collaborative recommender, what would change about this pivot table?**

# %%
pivot_df = pd.pivot_table(df, index = 'title', columns ='userId', values='rating')
pivot_df.head()
# Out:
# userId                                   1    2    3    4    5    6    7    \
# title
# '71 (2014)                               NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 'Hellboy': The Seeds of Creation (2004)  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 'Round Midnight (1986)                   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 'Salem's Lot (2004)                      NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 'Til There Was You (1997)                NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# userId                                   8    9    10   ...  601  602  603  \
# title                                                   ...
# '71 (2014)                               NaN  NaN  NaN  ...  NaN  NaN  NaN
# 'Hellboy': The Seeds of Creation (2004)  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 'Round Midnight (1986)                   NaN  NaN  NaN  ...  NaN  NaN  NaN
# 'Salem's Lot (2004)                      NaN  NaN  NaN  ...  NaN  NaN  NaN
# 'Til There Was You (1997)                NaN  NaN  NaN  ...  NaN  NaN  NaN
#
# userId                                   604  605  606  607  608  609  610
# title
# '71 (2014)                               NaN  NaN  NaN  NaN  NaN  NaN  4.0
# 'Hellboy': The Seeds of Creation (2004)  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 'Round Midnight (1986)                   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 'Salem's Lot (2004)                      NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 'Til There Was You (1997)                NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 610 columns]

# %% [markdown]
# ## Create sparse matrix
# ---
#
# In a minute, we'll calculate the cosine similarity for each movie using the `pairwise_distances` function. Before that, we need to create a sparse matrix (datatype) using `scipy`'s `sparse` module like so:
# ```python
# sparse.csr_matrix(pivot.fillna(0))
# ```

# %%
sparse_pivot = sparse.csr_matrix(pivot_df.fillna(0))
print(sparse_pivot)
# Out:
#   (0, 609)	4.0
#   (1, 331)	4.0
#   (2, 331)	3.5
#   (2, 376)	3.5
#   (3, 344)	5.0
#   (4, 112)	3.0
#   (4, 344)	5.0
#   (5, 20)	1.5
#   (6, 11)	5.0
#   (6, 18)	2.0
#   (6, 90)	2.0
#   (6, 94)	3.0
#   (6, 171)	4.0
#   (6, 216)	4.0
#   (6, 287)	3.0
#   (6, 293)	1.0
#   (6, 306)	3.5
#   (6, 376)	3.5
#   (6, 413)	3.0
#   (6, 473)	1.0
#   (6, 476)	3.5
#   (6, 519)	4.0
#   (6, 554)	5.0
#   (6, 560)	4.5
#   (6, 598)	2.0
#   :	:
#   (9717, 26)	5.0
#   (9717, 41)	5.0
#   (9717, 56)	2.0
#   (9717, 67)	4.0
#   (9717, 87)	3.5
#   (9717, 140)	3.5
#   (9717, 197)	2.0
#   (9717, 214)	2.5
#   (9717, 216)	2.0
#   (9717, 220)	3.5
#   (9717, 238)	3.0
#   (9717, 281)	4.0
#   (9717, 293)	4.0
#   (9717, 306)	2.5
#   (9717, 312)	1.0
#   (9717, 413)	3.0
#   (9717, 420)	3.0
#   (9717, 447)	3.0
#   (9717, 473)	3.0
#   (9717, 476)	3.5
#   (9717, 554)	3.0
#   (9717, 560)	4.0
#   (9717, 596)	3.0
#   (9717, 598)	2.5
#   (9718, 526)	1.0

# %% [markdown]
# ## Calculate cosine similarity
# ---
#
# `sklearn` has a built-in `pairwise_distances` function that we can use for our recommender. It will return a square matrix, comparing every movie with every other movie in the dataset.
#
# ```python
# pairwise_distances(sparse_pivot, metric='cosine')
# ```

# %%
recommender = pairwise_distances(sparse_pivot,metric ='cosine')
recommender.shape
# Out:
# (9719, 9719)

# %% [markdown]
# ## Create distances DataFrame
# ---
#
# At this point, we essentially have a recommender. We'll load it into a `pandas` DataFrame for readability.
#
# You'll notice that each movie has a "distance" of 0 with itself (along the diagonal).

# %%
recommender_df = pd.DataFrame(recommender, columns=pivot_df.index, index = pivot_df.index)
recommender_df.head()
# Out:
# title                                    '71 (2014)  \
# title
# '71 (2014)                                      0.0
# 'Hellboy': The Seeds of Creation (2004)         1.0
# 'Round Midnight (1986)                          1.0
# 'Salem's Lot (2004)                             1.0
# 'Til There Was You (1997)                       1.0
#
# title                                    'Hellboy': The Seeds of Creation (2004)  \
# title
# '71 (2014)                                                              1.000000
# 'Hellboy': The Seeds of Creation (2004)                                 0.000000
# 'Round Midnight (1986)                                                  0.292893
# 'Salem's Lot (2004)                                                     1.000000
# 'Til There Was You (1997)                                               1.000000
#
# title                                    'Round Midnight (1986)  \
# title
# '71 (2014)                                             1.000000
# 'Hellboy': The Seeds of Creation (2004)                0.292893
# 'Round Midnight (1986)                                 0.000000
# 'Salem's Lot (2004)                                    1.000000
# 'Til There Was You (1997)                              1.000000
#
# title                                    'Salem's Lot (2004)  \
# title
# '71 (2014)                                          1.000000
# 'Hellboy': The Seeds of Creation (2004)             1.000000
# 'Round Midnight (1986)                              1.000000
# 'Salem's Lot (2004)                                 0.000000
# 'Til There Was You (1997)                           0.142507
#
# title                                    'Til There Was You (1997)  \
# title
# '71 (2014)                                                1.000000
# 'Hellboy': The Seeds of Creation (2004)                   1.000000
# 'Round Midnight (1986)                                    1.000000
# 'Salem's Lot (2004)                                       0.142507
# 'Til There Was You (1997)                                 0.000000
#
# title                                    'Tis the Season for Love (2015)  \
# title
# '71 (2014)                                                           1.0
# 'Hellboy': The Seeds of Creation (2004)                              1.0
# 'Round Midnight (1986)                                               1.0
# 'Salem's Lot (2004)                                                  1.0
# 'Til There Was You (1997)                                            1.0
#
# title                                    'burbs, The (1989)  \
# title
# '71 (2014)                                         1.000000
# 'Hellboy': The Seeds of Creation (2004)            1.000000
# 'Round Midnight (1986)                             0.823223
# 'Salem's Lot (2004)                                1.000000
# 'Til There Was You (1997)                          1.000000
#
# title                                    'night Mother (1986)  \
# title
# '71 (2014)                                                1.0
# 'Hellboy': The Seeds of Creation (2004)                   1.0
# 'Round Midnight (1986)                                    1.0
# 'Salem's Lot (2004)                                       1.0
# 'Til There Was You (1997)                                 1.0
#
# title                                    (500) Days of Summer (2009)  \
# title
# '71 (2014)                                                  0.858347
# 'Hellboy': The Seeds of Creation (2004)                     1.000000
# 'Round Midnight (1986)                                      1.000000
# 'Salem's Lot (2004)                                         1.000000
# 'Til There Was You (1997)                                   1.000000
#
# title                                    *batteries not included (1987)  ...  \
# title                                                                    ...
# '71 (2014)                                                          1.0  ...
# 'Hellboy': The Seeds of Creation (2004)                             1.0  ...
# 'Round Midnight (1986)                                              1.0  ...
# 'Salem's Lot (2004)                                                 1.0  ...
# 'Til There Was You (1997)                                           1.0  ...
#
# title                                    Zulu (2013)  [REC] (2007)  \
# title
# '71 (2014)                                       1.0      0.657945
# 'Hellboy': The Seeds of Creation (2004)          1.0      1.000000
# 'Round Midnight (1986)                           1.0      1.000000
# 'Salem's Lot (2004)                              1.0      1.000000
# 'Til There Was You (1997)                        1.0      1.000000
#
# title                                    [REC]² (2009)  \
# title
# '71 (2014)                                    0.456695
# 'Hellboy': The Seeds of Creation (2004)       1.000000
# 'Round Midnight (1986)                        1.000000
# 'Salem's Lot (2004)                           1.000000
# 'Til There Was You (1997)                     1.000000
#
# title                                    [REC]³ 3 Génesis (2012)  \
# title
# '71 (2014)                                              0.292893
# 'Hellboy': The Seeds of Creation (2004)                 1.000000
# 'Round Midnight (1986)                                  1.000000
# 'Salem's Lot (2004)                                     1.000000
# 'Til There Was You (1997)                               1.000000
#
# title                                    anohana: The Flower We Saw That Day - The Movie (2013)  \
# title
# '71 (2014)                                                                             1.0
# 'Hellboy': The Seeds of Creation (2004)                                                1.0
# 'Round Midnight (1986)                                                                 1.0
# 'Salem's Lot (2004)                                                                    1.0
# 'Til There Was You (1997)                                                              1.0
#
# title                                    eXistenZ (1999)  xXx (2002)  \
# title
# '71 (2014)                                           1.0    0.860569
# 'Hellboy': The Seeds of Creation (2004)              1.0    1.000000
# 'Round Midnight (1986)                               1.0    1.000000
# 'Salem's Lot (2004)                                  1.0    1.000000
# 'Til There Was You (1997)                            1.0    1.000000
#
# title                                    xXx: State of the Union (2005)  \
# title
# '71 (2014)                                                     0.672673
# 'Hellboy': The Seeds of Creation (2004)                        1.000000
# 'Round Midnight (1986)                                         1.000000
# 'Salem's Lot (2004)                                            1.000000
# 'Til There Was You (1997)                                      1.000000
#
# title                                    ¡Three Amigos! (1986)  \
# title
# '71 (2014)                                                 1.0
# 'Hellboy': The Seeds of Creation (2004)                    1.0
# 'Round Midnight (1986)                                     1.0
# 'Salem's Lot (2004)                                        1.0
# 'Til There Was You (1997)                                  1.0
#
# title                                    À nous la liberté (Freedom for Us) (1931)
# title
# '71 (2014)                                                                     1.0
# 'Hellboy': The Seeds of Creation (2004)                                        1.0
# 'Round Midnight (1986)                                                         1.0
# 'Salem's Lot (2004)                                                            1.0
# 'Til There Was You (1997)                                                      1.0
#
# [5 rows x 9719 columns]

# %% [markdown]
# ## Evaluate recommender performance
# ---
#
# Now comes the fun part! Let's check out a few movies to see if the recommender aligns with our intuition. In the cell below we'll do the following:
# 1. Create a search term
# 2. Use that to find all titles matching the search query
# 3. For each title, we'll list off the following:
#   1. The average rating
#   2. The number of ratings
#   3. The ten most similar movies

# %%
search_term = 'Die Hard'
movies.loc[movies['title'].str.contains(search_term),'title']
# Out:
# 138     Die Hard: With a Vengeance (1995)
# 793                       Die Hard (1988)
# 1053                    Die Hard 2 (1990)
# 6518         Live Free or Die Hard (2007)
# 8103       Good Day to Die Hard, A (2013)
# Name: title, dtype: object

# %%
pivot_df.shape
# Out:
# (9719, 610)

# %%
610 -pivot_df.T['Die Hard (1988)'].isnull().sum()
# Out:
# 145

# %%
search_term ='Resident Evil'
for title in movies.loc[movies['title'].str.contains(search_term),'title']:
    print(title)
    print('Average Rating', pivot_df.loc[title,:].mean())
    print('Number of ratings',pivot_df.loc[title,:].count())
    print('Closest 10 movies')
    print(recommender_df[title].sort_values()[1:10])
    print(' ')
# Out:
# Resident Evil (2002)
# Average Rating 3.0833333333333335
# Number of ratings 30
# Closest 10 movies
# title
# Resident Evil: Extinction (2007)             0.380186
# Evolution (2001)                             0.417264
# xXx (2002)                                   0.449497
# Hellboy (2004)                               0.451575
# Die Another Day (2002)                       0.462695
# Transporter, The (2002)                      0.487102
# Rundown, The (2003)                          0.488801
# Terminator 3: Rise of the Machines (2003)    0.490444
# Death Proof (2007)                           0.490800
# Name: Resident Evil (2002), dtype: float64
#
# Resident Evil: Apocalypse (2004)
# Average Rating 2.9285714285714284
# Number of ratings 14
# Closest 10 movies
# title
# Resident Evil: Extinction (2007)    0.385595
# Resident Evil: Afterlife (2010)     0.396149
# Freddy vs. Jason (2003)             0.421241
# Underworld: Evolution (2006)        0.473237
# Final Destination 3 (2006)          0.475673
# Final Destination 2 (2003)          0.486036
# Ninja Assassin (2009)               0.502172
# 28 Weeks Later (2007)               0.509275
# Unknown (2011)                      0.509461
# Name: Resident Evil: Apocalypse (2004), dtype: float64
#
# Resident Evil: Extinction (2007)
# Average Rating 2.95
# Number of ratings 10
# Closest 10 movies
# title
# Freddy vs. Jason (2003)             0.373662
# Resident Evil (2002)                0.380186
# Resident Evil: Apocalypse (2004)    0.385595
# Final Destination 3 (2006)          0.391695
# Transporter 2 (2005)                0.407813
# Final Destination 2 (2003)          0.415339
# Ninja Assassin (2009)               0.426372
# Underworld: Evolution (2006)        0.463096
# Buried (2010)                       0.466604
# Name: Resident Evil: Extinction (2007), dtype: float64
#
# Resident Evil: Afterlife (2010)
# Average Rating 3.142857142857143
# Number of ratings 7
# Closest 10 movies
# title
# 12 Rounds (2009)                     0.324263
# Resident Evil: Retribution (2012)    0.377918
# Buried (2010)                        0.384486
# Resident Evil: Apocalypse (2004)     0.396149
# Priest (2011)                        0.419709
# Scream 4 (2011)                      0.426075
# Salt (2010)                          0.428821
# Battle: Los Angeles (2011)           0.440320
# Underworld: Awakening (2012)         0.448630
# Name: Resident Evil: Afterlife (2010), dtype: float64
#
# Resident Evil: Retribution (2012)
# Average Rating 3.75
# Number of ratings 2
# Closest 10 movies
# title
# House at the End of the Street (2012)    0.247423
# Spiral (2007)                            0.247423
# Byzantium (2012)                         0.247423
# Prison Break: The Final Break (2009)     0.247423
# Exam (2009)                              0.300846
# Dark Skies (2013)                        0.326875
# Underworld: Awakening (2012)             0.333877
# Beowulf & Grendel (2005)                 0.341495
# Chaos (2005)                             0.341495
# Name: Resident Evil: Retribution (2012), dtype: float64
